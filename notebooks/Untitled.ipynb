# %%
import numpy as np
import pandas as pd

pd.read_csv('../data/raw/CRCP_Coral_Demographic_Survey_USVI_4f08_0ab5_9d84.csv')
# Out:
#                      time       latitude     longitude  region  \
# 0                     UTC  degrees_north  degrees_east     NaN
# 1    2017-08-02T00:00:00Z       18.35779     -64.77686  STTSTJ
# 2    2017-08-02T00:00:00Z       18.36237     -64.75802  STTSTJ
# 3    2017-08-02T00:00:00Z       18.36735     -64.75844  STTSTJ
# 4    2017-08-02T00:00:00Z       18.36437     -64.77161  STTSTJ
# ..                    ...            ...           ...     ...
# 858  2017-08-02T00:00:00Z       18.35779     -64.77686  STTSTJ
# 859  2017-08-02T00:00:00Z       18.36237     -64.75802  STTSTJ
# 860  2017-08-02T00:00:00Z       18.36735     -64.75844  STTSTJ
# 861  2017-08-02T00:00:00Z       18.36437     -64.77161  STTSTJ
# 862  2017-08-03T00:00:00Z       18.34387     -64.79642  STTSTJ
#
#                                 region_description  primary_sample_unit  \
# 0                                              NaN                  NaN
# ...
