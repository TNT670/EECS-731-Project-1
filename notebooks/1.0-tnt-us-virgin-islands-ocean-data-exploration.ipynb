# %%
import numpy as np
import pandas as pd

# %%
coral_data = pd.read_csv('../data/raw/CRCP_Coral_Demographic_Survey_USVI_4f08_0ab5_9d84.csv')
coral_data.head()
# Out:
#              time (UTC)  latitude (degrees_north)  longitude (degrees_east)  \
# 0  2017-08-02T00:00:00Z                  18.35779                 -64.77686
# 1  2017-08-02T00:00:00Z                  18.36237                 -64.75802
# 2  2017-08-02T00:00:00Z                  18.36735                 -64.75844
# 3  2017-08-02T00:00:00Z                  18.36437                 -64.77161
# 4  2017-08-03T00:00:00Z                  18.34387                 -64.79642
#
#    region                             region_description  primary_sample_unit  \
# 0  STTSTJ  St. Thomas and St. John - U.S. Virgin Islands                 6116
# 1  STTSTJ  St. Thomas and St. John - U.S. Virgin Islands                 6117
# 2  STTSTJ  St. Thomas and St. John - U.S. Virgin Islands                 6118
# 3  STTSTJ  St. Thomas and St. John - U.S. Virgin Islands                 6331
# 4  STTSTJ  St. Thomas and St. John - U.S. Virgin Islands                 6352
#
#    station_nr              date_utc      strat  \
# 0           1  2017-08-02T00:00:00Z  PTRF_DEEP
# 1           1  2017-08-02T00:00:00Z  PTRF_DEEP
# 2           1  2017-08-02T00:00:00Z  PTRF_DEEP
# 3           1  2017-08-02T00:00:00Z  PTRF_DEEP
# 4           1  2017-08-03T00:00:00Z  PTRF_DEEP
#
#                             strat_description  ... depth_strat_description  \
# 0  Patch reef (Aggregate and individual) deep  ...          deep (12-30 m)
# 1  Patch reef (Aggregate and individual) deep  ...          deep (12-30 m)
# 2  Patch reef (Aggregate and individual) deep  ...          deep (12-30 m)
# 3  Patch reef (Aggregate and individual) deep  ...          deep (12-30 m)
# 4  Patch reef (Aggregate and individual) deep  ...          deep (12-30 m)
#
#   species_cd          species_name max_diameter (cm) perp_diameter (cm)  \
# 0   ACR CERV  Acropora cervicornis               NaN                NaN
# 1   ACR CERV  Acropora cervicornis               NaN                NaN
# 2   ACR CERV  Acropora cervicornis               NaN                NaN
# 3   ACR CERV  Acropora cervicornis               NaN                NaN
# 4   ACR CERV  Acropora cervicornis               NaN                NaN
#
#   height (cm) old_mort (percentage)  recent_mort (percentage)  \
# 0         NaN                   NaN                       NaN
# 1         NaN                   NaN                       NaN
# 2         NaN                   NaN                       NaN
# 3         NaN                   NaN                       NaN
# 4         NaN                   NaN                       NaN
#
#    bleach_condition  disease
# 0               NaN      NaN
# 1               NaN      NaN
# 2               NaN      NaN
# 3               NaN      NaN
# 4               NaN      NaN
#
# [5 rows x 24 columns]

# %%
fish_data = pd.read_csv('../data/raw/CRCP_Reef_Fish_Surveys_USVI_0a61_f090_a5e8.csv')
fish_data.head()
# Out:
#              time (UTC)  latitude (degrees_north)  longitude (degrees_east)  \
# 0  2017-08-02T00:00:00Z                  18.35779                 -64.77686
# 1  2017-08-02T00:00:00Z                  18.35779                 -64.77686
# 2  2017-08-02T00:00:00Z                  18.35779                 -64.77686
# 3  2017-08-02T00:00:00Z                  18.35779                 -64.77686
# 4  2017-08-02T00:00:00Z                  18.35779                 -64.77686
#
#                date_utc  primary_sample_unit  station_nr  sample_depth (m)  \
# 0  2017-08-02T00:00:00Z                 6116           1              13.0
# 1  2017-08-02T00:00:00Z                 6116           1              13.0
# 2  2017-08-02T00:00:00Z                 6116           1              13.0
# 3  2017-08-02T00:00:00Z                 6116           1              13.0
# 4  2017-08-02T00:00:00Z                 6116           1              13.0
#
#   habitat_cd                           habitat_type depth_strat  ...  \
# 0       PTRF  Patch reef (Aggregate and individual)        DEEP  ...
# 1       PTRF  Patch reef (Aggregate and individual)        DEEP  ...
# 2       PTRF  Patch reef (Aggregate and individual)        DEEP  ...
# 3       PTRF  Patch reef (Aggregate and individual)        DEEP  ...
# 4       PTRF  Patch reef (Aggregate and individual)        DEEP  ...
#
#   sub_region_name_description admin    administration_description  \
# 0                    St. John  VIIS  Virgin Islands National Park
# 1                    St. John  VIIS  Virgin Islands National Park
# 2                    St. John  VIIS  Virgin Islands National Park
# 3                    St. John  VIIS  Virgin Islands National Park
# 4                    St. John  VIIS  Virgin Islands National Park
#
#         scientific_name          common_name len (cm)  num  time_seen  \
# 0      Apogon binotatus  barred cardinalfish      0.0  0.0          1
# 1  Gymnothorax miliaris     goldentail moray      0.0  0.0          1
# 2  Monacanthus ciliatus     fringed filefish      0.0  0.0          1
# 3   Acanthurus bahianus        ocean surgeon      8.0  0.0          1
# 4   Acanthurus bahianus        ocean surgeon     10.0  1.0          1
#
#        strat                           strat_description
# 0  PTRF_DEEP  Patch reef (Aggregate and individual) deep
# 1  PTRF_DEEP  Patch reef (Aggregate and individual) deep
# 2  PTRF_DEEP  Patch reef (Aggregate and individual) deep
# 3  PTRF_DEEP  Patch reef (Aggregate and individual) deep
# 4  PTRF_DEEP  Patch reef (Aggregate and individual) deep
#
# [5 rows x 22 columns]

# %%
ocean_survey = pd.merge(coral_data, fish_data, on=['admin', 'administration_description', 'strat', 'strat_description'])
ocean_survey.head()
# Out:
#            time (UTC)_x  latitude (degrees_north)_x  \
# 0  2017-08-02T00:00:00Z                    18.35779
# 1  2017-08-02T00:00:00Z                    18.35779
# 2  2017-08-02T00:00:00Z                    18.35779
# 3  2017-08-02T00:00:00Z                    18.35779
# 4  2017-08-02T00:00:00Z                    18.35779
#
#    longitude (degrees_east)_x  region  \
# 0                   -64.77686  STTSTJ
# 1                   -64.77686  STTSTJ
# 2                   -64.77686  STTSTJ
# 3                   -64.77686  STTSTJ
# 4                   -64.77686  STTSTJ
#
#                               region_description  primary_sample_unit_x  \
# 0  St. Thomas and St. John - U.S. Virgin Islands                   6116
# 1  St. Thomas and St. John - U.S. Virgin Islands                   6116
# 2  St. Thomas and St. John - U.S. Virgin Islands                   6116
# 3  St. Thomas and St. John - U.S. Virgin Islands                   6116
# 4  St. Thomas and St. John - U.S. Virgin Islands                   6116
#
#    station_nr_x            date_utc_x      strat  \
# 0             1  2017-08-02T00:00:00Z  PTRF_DEEP
# 1             1  2017-08-02T00:00:00Z  PTRF_DEEP
# 2             1  2017-08-02T00:00:00Z  PTRF_DEEP
# 3             1  2017-08-02T00:00:00Z  PTRF_DEEP
# 4             1  2017-08-02T00:00:00Z  PTRF_DEEP
#
#                             strat_description  ...  \
# 0  Patch reef (Aggregate and individual) deep  ...
# 1  Patch reef (Aggregate and individual) deep  ...
# 2  Patch reef (Aggregate and individual) deep  ...
# 3  Patch reef (Aggregate and individual) deep  ...
# 4  Patch reef (Aggregate and individual) deep  ...
#
#                             habitat_type depth_strat_y  \
# 0  Patch reef (Aggregate and individual)          DEEP
# 1  Patch reef (Aggregate and individual)          DEEP
# 2  Patch reef (Aggregate and individual)          DEEP
# 3  Patch reef (Aggregate and individual)          DEEP
# 4  Patch reef (Aggregate and individual)          DEEP
#
#   depth_strat_description_y sub_region sub_region_name_description  \
# 0            deep (12-30 m)        STJ                    St. John
# 1            deep (12-30 m)        STJ                    St. John
# 2            deep (12-30 m)        STJ                    St. John
# 3            deep (12-30 m)        STJ                    St. John
# 4            deep (12-30 m)        STJ                    St. John
#
#         scientific_name          common_name  len (cm)  num  time_seen
# 0      Apogon binotatus  barred cardinalfish       0.0  0.0          1
# 1  Gymnothorax miliaris     goldentail moray       0.0  0.0          1
# 2  Monacanthus ciliatus     fringed filefish       0.0  0.0          1
# 3   Acanthurus bahianus        ocean surgeon       8.0  0.0          1
# 4   Acanthurus bahianus        ocean surgeon      10.0  1.0          1
#
# [5 rows x 42 columns]
